# %%
import pandas as pd
import os
import numpy as np

# %%
# JC-201904-citibike-tripdata.csv

april_19_df = pd.read_csv(os.path.join("data", "JC-201904-citibike-tripdata.csv"))
april_19_df.head()
#april_19_df.dtypes
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
# april_19_df['tripduration'] = pd.to_datetime(april_19_df['tripduration'],unit="s")

# %%
#april_19_df['started_at'] = pd.to_datetime(april_19_df['starttime'])
#april_19_df['ended_at'] = pd.to_datetime(april_19_df['stoptime'])

# %%
#april_19_df["tripduration2"] = (april_19_df['ended_at'] - april_19_df['started_at'])

# %%
from datetime import datetime

# %%
april_19_df["triptime"] = (april_19_df['tripduration'] / 60)

# %%
april_19_df = april_19_df.round({'triptime': 2})

# %%
april_19_df["year"] = ('2019')

# %%
april_19_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
conditions = [
    (april_19_df['triptime'] <= 1),
    (april_19_df['triptime'] > 1) & (april_19_df['triptime'] <= 2),
    (april_19_df['triptime'] > 2) & (april_19_df['triptime'] <= 5),
    (april_19_df['triptime'] > 5) & (april_19_df['triptime'] <= 10),
    (april_19_df['triptime'] > 10) & (april_19_df['triptime'] <= 20),
    (april_19_df['triptime'] > 20)
    ]

values = ['0-1', '1-2', '2-5', '5-10', '10-20', '20+']

# %%
april_19_df['timebucket'] = np.select(conditions,values)

# %%
april_19_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
# april_19_df = april_19_df.drop(['tripduration'], axis=1)
# april_19_df = april_19_df.rename(columns={"tripduration2": "tripduration"})
# april_19_df.head()

# %%
april_19_df.to_csv("bikes_april_2019.csv", index=False)

# %%
april_20_df = pd.read_csv(os.path.join("data", "JC-202004-citibike-tripdata.csv"))

# %%
april_19_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
april_20_df["triptime"] = (april_20_df['tripduration'] / 60)
april_20_df = april_20_df.round({'triptime': 2})
april_20_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1437  2020-04-01 01:06:20.6300  2020-04-01 01:30:17.9680
# 1           264  2020-04-01 05:02:42.0570  2020-04-01 05:07:06.1260
# 2           254  2020-04-01 06:20:28.1190  2020-04-01 06:24:42.1380
# 3           429  2020-04-01 06:33:30.5170  2020-04-01 06:40:40.1990
# 4           805  2020-04-01 06:38:32.9220  2020-04-01 06:51:58.2050
#
#    start station id start station name  start station latitude  \
# 0              3678      Fairmount Ave               40.725726
# 1              3207        Oakland Ave               40.737604
# 2              3678      Fairmount Ave               40.725726
# 3              3195            Sip Ave               40.730897
# 4              3193       Lincoln Park               40.724605
#
#    start station longitude  end station id end station name  \
# 0               -74.071959            3678    Fairmount Ave
# ...

# %%
april_20_df["year"] = ('2020')

# %%
conditions = [
    (april_20_df['triptime'] <= 1),
    (april_20_df['triptime'] > 1) & (april_20_df['triptime'] <= 2),
    (april_20_df['triptime'] > 2) & (april_20_df['triptime'] <= 5),
    (april_20_df['triptime'] > 5) & (april_20_df['triptime'] <= 10),
    (april_20_df['triptime'] > 10) & (april_20_df['triptime'] <= 20),
    (april_20_df['triptime'] > 20)
    ]

values = ['0-1', '1-2', '2-5', '5-10', '10-20', '20+']

# %%
april_20_df['timebucket'] = np.select(conditions,values)

# %%
april_19_20_df = april_19_df.append(april_20_df, ignore_index=True)
april_19_20_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
april_19_20_df.to_csv("bikes_april_19_20.csv", index=False)

# %%
#april_21_df = pd.read_csv(os.path.join("data", "JC-202104-citibike-tripdata.csv"))
#april_21_df.head()
#april_21_df.dtypes

# %%
#april_21_df['started_at'] = pd.to_datetime(april_21_df['started_at'])

# %%
#april_21_df['ended_at'] = pd.to_datetime(april_21_df['ended_at'])

# %%
#april_21_df.dtypes

# %%
#april_21_df["tripduration"] = (april_21_df['ended_at'] - april_21_df['started_at'])

# %%
#april_21_df.head()

# %%
#april_22_df = pd.read_csv(os.path.join("data", "JC-202204-citibike-tripdata.csv"))
#april_22_df.head()
#april_22_df.dtypes

# %%
july_21_df = pd.read_csv(os.path.join("data", "JC-202107-citibike-tripdata.csv"))
july_21_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  C9446233AFAB8896   classic_bike  2021-07-15 19:27:25  2021-07-15 19:27:35
# 1  0C3D69370BE39992  electric_bike  2021-07-22 06:41:54  2021-07-22 06:42:03
# 2  3B0390B706281176   classic_bike  2021-07-19 06:36:13  2021-07-19 06:38:18
# 3  9AFBC07247ABE507   classic_bike  2021-07-08 06:33:45  2021-07-08 06:35:53
# 4  ADB073F7FFC372D3   classic_bike  2021-07-21 07:33:49  2021-07-21 08:00:14
#
#                   start_station_name start_station_id  \
# 0                     Journal Square            JC103
# 1                     Journal Square            JC103
# 2                    Brunswick & 6th            JC081
# 3                    Brunswick & 6th            JC081
# 4  14 St Ferry - 14 St & Shipyard Ln            HB202
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0              Journal Square          JC103  40.733670 -74.062500  40.733670
# ...

# %%
#july_21_df['started_at'] = july_21_df['started_at'].str[-8:]
#july_21_df['ended_at'] = july_21_df['ended_at'].str[-8:]

# %%
# july_21_df['started_at'] = pd.to_datetime(july_21_df['started_at'],format= '%H:%M:%S' ).dt.time
# july_21_df['ended_at'] = pd.to_datetime(july_21_df['ended_at'],format= '%H:%M:%S' ).dt.time

# %%
#july_21_df['started_at'] = [time.time() for time in july_21_df['started_at']]
#july_21_df['ended_at'] = [time.time() for time in july_21_df['started_at']]

# %%
july_21_df['started_at'] = pd.to_datetime(july_21_df['started_at'])
july_21_df['ended_at'] = pd.to_datetime(july_21_df['ended_at'])

# %%
july_21_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C9446233AFAB8896   classic_bike 2021-07-15 19:27:25 2021-07-15 19:27:35
# 1  0C3D69370BE39992  electric_bike 2021-07-22 06:41:54 2021-07-22 06:42:03
# 2  3B0390B706281176   classic_bike 2021-07-19 06:36:13 2021-07-19 06:38:18
# 3  9AFBC07247ABE507   classic_bike 2021-07-08 06:33:45 2021-07-08 06:35:53
# 4  ADB073F7FFC372D3   classic_bike 2021-07-21 07:33:49 2021-07-21 08:00:14
#
#                   start_station_name start_station_id  \
# 0                     Journal Square            JC103
# 1                     Journal Square            JC103
# 2                    Brunswick & 6th            JC081
# 3                    Brunswick & 6th            JC081
# 4  14 St Ferry - 14 St & Shipyard Ln            HB202
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0              Journal Square          JC103  40.733670 -74.062500  40.733670
# ...

# %%
july_21_df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# dtype: object

# %%
july_21_df['tripduration'] = (july_21_df['ended_at'] - july_21_df['started_at'])
july_21_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C9446233AFAB8896   classic_bike 2021-07-15 19:27:25 2021-07-15 19:27:35
# 1  0C3D69370BE39992  electric_bike 2021-07-22 06:41:54 2021-07-22 06:42:03
# 2  3B0390B706281176   classic_bike 2021-07-19 06:36:13 2021-07-19 06:38:18
# 3  9AFBC07247ABE507   classic_bike 2021-07-08 06:33:45 2021-07-08 06:35:53
# 4  ADB073F7FFC372D3   classic_bike 2021-07-21 07:33:49 2021-07-21 08:00:14
#
#                   start_station_name start_station_id  \
# 0                     Journal Square            JC103
# 1                     Journal Square            JC103
# 2                    Brunswick & 6th            JC081
# 3                    Brunswick & 6th            JC081
# 4  14 St Ferry - 14 St & Shipyard Ln            HB202
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0              Journal Square          JC103  40.733670 -74.062500  40.733670
# ...

# %%
july_21_df['tripduration'] = pd.to_numeric(july_21_df['tripduration'].dt.seconds, downcast='integer')

# %%
july_21_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C9446233AFAB8896   classic_bike 2021-07-15 19:27:25 2021-07-15 19:27:35
# 1  0C3D69370BE39992  electric_bike 2021-07-22 06:41:54 2021-07-22 06:42:03
# 2  3B0390B706281176   classic_bike 2021-07-19 06:36:13 2021-07-19 06:38:18
# 3  9AFBC07247ABE507   classic_bike 2021-07-08 06:33:45 2021-07-08 06:35:53
# 4  ADB073F7FFC372D3   classic_bike 2021-07-21 07:33:49 2021-07-21 08:00:14
#
#                   start_station_name start_station_id  \
# 0                     Journal Square            JC103
# 1                     Journal Square            JC103
# 2                    Brunswick & 6th            JC081
# 3                    Brunswick & 6th            JC081
# 4  14 St Ferry - 14 St & Shipyard Ln            HB202
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0              Journal Square          JC103  40.733670 -74.062500  40.733670
# ...

# %%
dec_21_df = pd.read_csv(os.path.join("data", "JC-202112-citibike-tripdata.csv"))
dec_21_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  87F1811D08BA7BF3   classic_bike  2021-12-12 09:16:59  2021-12-12 09:23:08
# 1  48390A4B390ABD36  electric_bike  2021-12-07 20:06:14  2021-12-07 20:14:14
# 2  93AE14B47CBB30F8   classic_bike  2021-12-31 16:07:10  2021-12-31 16:14:39
# 3  5D0BDBFB30D7C9F6  electric_bike  2021-12-11 03:25:41  2021-12-11 03:31:16
# 4  D6382ADAF1672DD8   classic_bike  2021-12-17 10:59:28  2021-12-17 11:12:41
#
#   start_station_name start_station_id       end_station_name end_station_id  \
# 0      Hamilton Park            JC009          Grove St PATH          JC005
# 1      Hamilton Park            JC009                Hilltop          JC019
# 2       Brunswick St            JC023           Brunswick St          JC023
# 3       Brunswick St            JC023  Baldwin at Montgomery          JC020
# 4       Brunswick St            JC023            Paulus Hook          JC002
#
# ...

# %%
dec_21_df['started_at'] = pd.to_datetime(dec_21_df['started_at'])
dec_21_df['ended_at'] = pd.to_datetime(dec_21_df['ended_at'])
dec_21_df['tripduration'] = (dec_21_df['ended_at'] - dec_21_df['started_at'])
dec_21_df['tripduration'] = pd.to_numeric(dec_21_df['tripduration'].dt.seconds, downcast='integer')
dec_21_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  87F1811D08BA7BF3   classic_bike 2021-12-12 09:16:59 2021-12-12 09:23:08
# 1  48390A4B390ABD36  electric_bike 2021-12-07 20:06:14 2021-12-07 20:14:14
# 2  93AE14B47CBB30F8   classic_bike 2021-12-31 16:07:10 2021-12-31 16:14:39
# 3  5D0BDBFB30D7C9F6  electric_bike 2021-12-11 03:25:41 2021-12-11 03:31:16
# 4  D6382ADAF1672DD8   classic_bike 2021-12-17 10:59:28 2021-12-17 11:12:41
#
#   start_station_name start_station_id       end_station_name end_station_id  \
# 0      Hamilton Park            JC009          Grove St PATH          JC005
# 1      Hamilton Park            JC009                Hilltop          JC019
# 2       Brunswick St            JC023           Brunswick St          JC023
# 3       Brunswick St            JC023  Baldwin at Montgomery          JC020
# 4       Brunswick St            JC023            Paulus Hook          JC002
#
# ...

# %%
july_21_df["month"] = ('july')


july_21_df["triptime"] = (july_21_df['tripduration'] / 60)
july_21_df = july_21_df.round({'triptime': 2})



conditions = [
    (july_21_df['triptime'] <= 1),
    (july_21_df['triptime'] > 1) & (july_21_df['triptime'] <= 2),
    (july_21_df['triptime'] > 2) & (july_21_df['triptime'] <= 5),
    (july_21_df['triptime'] > 5) & (july_21_df['triptime'] <= 10),
    (july_21_df['triptime'] > 10) & (july_21_df['triptime'] <= 20),
    (july_21_df['triptime'] > 20)
    ]

values = ['0-1', '1-2', '2-5', '5-10', '10-20', '20+']

july_21_df['timebucket'] = np.select(conditions,values)

july_21_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C9446233AFAB8896   classic_bike 2021-07-15 19:27:25 2021-07-15 19:27:35
# 1  0C3D69370BE39992  electric_bike 2021-07-22 06:41:54 2021-07-22 06:42:03
# 2  3B0390B706281176   classic_bike 2021-07-19 06:36:13 2021-07-19 06:38:18
# 3  9AFBC07247ABE507   classic_bike 2021-07-08 06:33:45 2021-07-08 06:35:53
# 4  ADB073F7FFC372D3   classic_bike 2021-07-21 07:33:49 2021-07-21 08:00:14
#
#                   start_station_name start_station_id  \
# 0                     Journal Square            JC103
# 1                     Journal Square            JC103
# 2                    Brunswick & 6th            JC081
# 3                    Brunswick & 6th            JC081
# 4  14 St Ferry - 14 St & Shipyard Ln            HB202
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0              Journal Square          JC103  40.733670 -74.062500  40.733670
# ...

# %%
dec_21_df["month"] = ('december')

dec_21_df["triptime"] = (dec_21_df['tripduration'] / 60)
dec_21_df = dec_21_df.round({'triptime': 2})

conditions = [
    (dec_21_df['triptime'] <= 1),
    (dec_21_df['triptime'] > 1) & (dec_21_df['triptime'] <= 2),
    (dec_21_df['triptime'] > 2) & (dec_21_df['triptime'] <= 5),
    (dec_21_df['triptime'] > 5) & (dec_21_df['triptime'] <= 10),
    (dec_21_df['triptime'] > 10) & (dec_21_df['triptime'] <= 20),
    (dec_21_df['triptime'] > 20)
    ]

values = ['0-1', '1-2', '2-5', '5-10', '10-20', '20+']

dec_21_df['timebucket'] = np.select(conditions,values)

dec_21_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  87F1811D08BA7BF3   classic_bike 2021-12-12 09:16:59 2021-12-12 09:23:08
# 1  48390A4B390ABD36  electric_bike 2021-12-07 20:06:14 2021-12-07 20:14:14
# 2  93AE14B47CBB30F8   classic_bike 2021-12-31 16:07:10 2021-12-31 16:14:39
# 3  5D0BDBFB30D7C9F6  electric_bike 2021-12-11 03:25:41 2021-12-11 03:31:16
# 4  D6382ADAF1672DD8   classic_bike 2021-12-17 10:59:28 2021-12-17 11:12:41
#
#   start_station_name start_station_id       end_station_name end_station_id  \
# 0      Hamilton Park            JC009          Grove St PATH          JC005
# 1      Hamilton Park            JC009                Hilltop          JC019
# 2       Brunswick St            JC023           Brunswick St          JC023
# 3       Brunswick St            JC023  Baldwin at Montgomery          JC020
# 4       Brunswick St            JC023            Paulus Hook          JC002
#
# ...

# %%
jul_dec_2021_df = july_21_df.append(dec_21_df, ignore_index=True)
jul_dec_2021_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C9446233AFAB8896   classic_bike 2021-07-15 19:27:25 2021-07-15 19:27:35
# 1  0C3D69370BE39992  electric_bike 2021-07-22 06:41:54 2021-07-22 06:42:03
# 2  3B0390B706281176   classic_bike 2021-07-19 06:36:13 2021-07-19 06:38:18
# 3  9AFBC07247ABE507   classic_bike 2021-07-08 06:33:45 2021-07-08 06:35:53
# 4  ADB073F7FFC372D3   classic_bike 2021-07-21 07:33:49 2021-07-21 08:00:14
#
#                   start_station_name start_station_id  \
# 0                     Journal Square            JC103
# 1                     Journal Square            JC103
# 2                    Brunswick & 6th            JC081
# 3                    Brunswick & 6th            JC081
# 4  14 St Ferry - 14 St & Shipyard Ln            HB202
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0              Journal Square          JC103  40.733670 -74.062500  40.733670
# ...

# %%
jul_dec_2021_df.to_csv("bikes_july_dec_2021.csv", index=False)
